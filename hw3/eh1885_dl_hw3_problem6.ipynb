# %% [markdown]
# ### Energy-based models assignment; implementation problem
#
# This is a (hopefully shorter, compared to hw2) implementation problem of the third assignment. We will investigate convolutional auto-encoders and denoising convolutional auto-encoders.

# %% [markdown]
# ### Prereqs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Question 1 (of this notebook):**
#
# Estimated time: 10 min.
#
# We first load the data.
#
# TODO:
# - Print out a few shapes. See comments in the below cell. Can be done in three lines of code, but you're welcome to provide a more complicated solution.

# %%
import datetime
import logging
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import numpy as np
import os
import time
import sys

import torch
import torch.nn as nn
from torch.optim import lr_scheduler
import torch.optim as optim
from torch.utils import data
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms

from torch.distributions.uniform import Uniform

denoising_path = '/content/drive/My Drive/hw3_best_denoising.pth'
nondenoising_path = '/content/drive/My Drive/hw3_best_nondenoising.pth'

def load_fashion_mnist(batch_size=64):
    # One convention (of the many) is to use a real number between -1 and 1
    # (inclusive) to represent each pixel; instead of an integer from 0 to 255.
    transform = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize([0.5], [0.5])])

    train_dataset = datasets.FashionMNIST(root='./data', train=True,
                                          download=True, transform=transform)

    # Create validation set from training set, given that torchvision only gives
    # us the train/test split.  
    num_train = len(train_dataset)
    indices = list(range(num_train))
    valid_size = 0.1
    split = int(np.floor(valid_size * num_train))

    random_seed = 123
    np.random.seed(random_seed)  # think: why do we do this?
    np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = data.SubsetRandomSampler(train_idx)
    valid_sampler = data.SubsetRandomSampler(valid_idx)
    train_loader = data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler)
    valid_loader = data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=valid_sampler)
    test_dataset = datasets.FashionMNIST(root='./data', train=False,
                                         download=True, transform=transform)
    test_loader = data.DataLoader(test_dataset, batch_size=batch_size,
                                  shuffle=False)
    
    # TODO: the images in training, validation, and test sets have shape:
    # [num of examples, image height, image weight];
    # write a few lines of code to print out the three (train/val/test) shapes;
    # for example, the test set image shape should be [10000, 28, 28];
    # try exploring the dataset using test_dataset[7], test_dataset.data, etc.
    print("Train Dataset size: [{},{},{}]"\
          .format(train_dataset.data.shape[0]- split, 
                  train_dataset.data.shape[1], 
                  train_dataset.data.shape[2]))
    print("Validation Dataset size: [{},{},{}]"\
          .format(split, 
                  train_dataset.data.shape[1], 
                  train_dataset.data.shape[2]))
    print("Test Dataset size: {}"\
          .format(test_dataset.data.shape))

    return train_loader, valid_loader, test_loader

def imshow(img, figsize=(12,12), transpose=True):
    # First unnormalize if we want to print out the image. We're using the
    # convention that each image pixel is between -1 and 1. But when python
    # prints out images, the pixel needs to be between 0 and 1.
    img = img / 2 + 0.5
    img_numpy = img.numpy()
    plt.figure(figsize=figsize)
    if transpose:
        img_numpy = img_numpy.transpose(1,2,0)
    plt.imshow(img_numpy)

# %%
batch_size = 64
train_loader, valid_loader, test_loader = load_fashion_mnist(batch_size)
# Out:
# Train Dataset size: [54000,28,28]
# Validation Dataset size: [6000,28,28]
# Test Dataset size: torch.Size([10000, 28, 28])

# %%
# !nvidia-smi  # make sure you're using GPUs when you are about to train the model
# Out:
# Fri Oct 30 18:23:12 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    12W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Taking a look at what the images are like
images = next(iter(test_loader))[0][:64]
imshow(torchvision.utils.make_grid(images, nrow=16))

# %%
torchvision.utils.make_grid(images, nrow=16).shape
# Out:
# torch.Size([3, 122, 482])

# %%
images.shape
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# Check out the ten classes on page 3: https://arxiv.org/pdf/1708.07747.pdf
# - 0: t-shirt/top; 1: trouser; 2: pullover; 3: dress; 4: coat; 5: sandals; 6: shirt; 7: sneaker; 8: bag; 9: ankle boots.
#
# <!-- For CIFAR10, check out the ten classes here: https://www.cs.toronto.edu/~kriz/cifar.html
# - Airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck -->
#
# This dataset is much more difficult on the classification task, compared to the digit MNIST which we saw in Lab 2. However, **today we will NOT be doing classification!!! So let's assume that the labels DO NOT EXIST in the iterators (the data loaders)!**

# %% [markdown]
# ### Model

# %% [markdown]
# Next, we will implement two versions of autoencoders: (1) convolutional autoencoder; (2) denoising convolutional autoencoder (but actually we'll be using the same model code, explained later).

# %% [markdown]
# **Question 2: implement a convolutional autoencoder**
#
# Estimated time: 30 min.
#
# TODO
# - In CAE class below, complete the init function and the forward function, such that your implementation satisfies the following requirements.
#   - The output image dimension (from the forward function) is exactly the same as the input image dimension.
#   - There are two Conv2d layer in the encoder, followed by three Conv2d or ConvTranspose2d blocks in the decoder. The out_channel for the second convolutional layer in the encoder should be >= 16 (for example, 16 or 32; feel free to experiment other choices).
#     - Use ReLU or some other similar nonlinearities, followed by pooling, after each convolution layer in the encoder.
#     - Use ReLU or some other similar nonlinearities, after each convolution layer in the decoder (except for the very last convolution layer). Suggestion (but no need to follow this advice): the out_channel size for the decoder convolutional layers should be smaller and smaller (meaning the out_channel for first decoding conv2d layer should be bigger than out_channel for second decoding conv2d layer).
#     - Add batch normalization layers after the nonlinearities, just like what you may have done in the previous homework.
#     - In decoder, if you want to obtain an output feature map with size larger than size of input feature map, consider using ConvTranspose2d, or UpsamplingBilinear2d, after figuring out what they do.
#     - No hard requirement on what padding or stride to use, but make sure they're small, given that our image is only 28*28.
#   - Note that your parameters (e.g., number of filters in the intermediate layers) should not be too big, given that our image is greyscale and has 28*28 pixels only.

# %%
cuda = torch.cuda.is_available()
device = torch.device('cuda' if cuda else 'cpu')

# %%
class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels=1, 
                      out_channels=16, 
                      kernel_size=3, 
                      padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(num_features = 16),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=16, 
                      out_channels=32, 
                      kernel_size=3, 
                      padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(num_features = 32),
            nn.MaxPool2d(2)
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(
                in_channels=32 , 
                out_channels=32, 
                kernel_size=3, 
                padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=32),
            nn.UpsamplingBilinear2d(scale_factor=2),
            nn.ConvTranspose2d(
                in_channels=32, 
                out_channels=16, 
                kernel_size=3, 
                padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(num_features=16),
            nn.UpsamplingBilinear2d(scale_factor=2), # replace with nn.functional.interpolate
            nn.ConvTranspose2d(
                in_channels=16, 
                out_channels=1, 
                kernel_size=3, 
                padding=1),
        )
        


    def forward(self, y):
        """Forward function of CAE class.

        Args:
          y: a batch of input images.
        
        Returns:
          yhat: the batch of reconstructed images.
        """
        z = self.encoder(y)
        yhat = self.decoder(z)
        return yhat

# %% [markdown]
# **Question 3: complete the train() and validate() function to be used later**
#
# Estimated time: 10 min.
#
# TODO
# - Complete the train() function.
#   - Hint: recall the five steps we discussed in Lab 2.
#   - Make sure your images are on GPUs (device cuda) before you train. Otherwise, your training may be extremely extremely slow and it may take you 50 times longer than other people.
#
# - Complete the validate() function:
#   - The only thing we need to do is to save the model when we achieve the best validation loss so far. So, check out the pytorch documentation or the third lab, for how to save checkpoints. Make sure to do this step because we need to load the model later.

# %%
# This is part of question 4.
def add_noise(images):
    normal_noise = torch.randn(images.shape) 
    
    unif = Uniform(0, 1)
    unif_noise = unif.sample((images.shape[0],))\
        .reshape((images.shape[0],1,1,1))
    
    images_noisy = torch.clamp(
        images + (unif_noise * normal_noise), 
        -1, 1)
    return images_noisy

# %%
def train(autoencoder, train_loader, epoch, num_epoch, learning_rate,
          weight_decay, log_interval, denoising=False):
    # Using sum reduction simply bc otherwise, the scale of the loss is too small;
    # given that we always have 28*28 images, using sum/mean reduction wouldn't
    # make a difference.
    criteria = nn.MSELoss(reduction='sum')
    optimizer = torch.optim.Adam(
        autoencoder.parameters(), lr=learning_rate)
    
    autoencoder.train()
    for i, data in enumerate(train_loader):
        images, _ = data
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        output = autoencoder(input_images)
        loss = criteria(output, images)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i + 1) % log_interval == 0:
            print('Epoch [{}/{}] - Iter[{}/{}], MSE loss:{:.6f}'.format(
                epoch + 1, num_epoch, i + 1,
                len(train_loader.dataset) // batch_size, loss.item() / batch_size
            ))


def validate(autoencoder, valid_loader, best_val_loss, denoising=False):
    total_loss = 0
    criteria = nn.MSELoss(reduction='sum')
    autoencoder.eval()
    for i, data in enumerate(valid_loader):
        images, _ = data
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        outputs = autoencoder(input_images)
        loss = criteria(outputs, images)
        total_loss += loss
    avg_loss = total_loss / (len(valid_loader) * batch_size)

    print('\nLoss per batch on validation set: {:.6f}'.format(avg_loss))

    if avg_loss < best_val_loss:
        if denoising:
            save_path = denoising_path
        else:
            save_path = nondenoising_path
        best_val_loss = avg_loss
        to_save = {'model': autoencoder.state_dict()}
        torch.save(to_save, save_path)
        print('Saved best model in the checkpoint directory\n')
    
    return best_val_loss

def evaluate(autoencoder, test_loader, denoising=False):
    total_loss = 0
    criteria = nn.MSELoss(reduction='sum')
    autoencoder.eval()
    for i, data in enumerate(test_loader):
        images, _ = data
        if denoising:
            input_images = add_noise(images)
        else:
            input_images = images
        if cuda:
            input_images = input_images.to(device)
            images = images.to(device)
        outputs = autoencoder(input_images)
        loss = criteria(outputs, images)
        total_loss += loss
    avg_loss = total_loss / (len(test_loader) * batch_size)

    print('\nMSE loss per batch on test set: {:.6f}'.format(avg_loss))

# %% [markdown]
# **Question 4: implement a denoising convolutional autoencoder**
#
# Estimated time: 20 min.
#
# The input to a denoising CAE is a perturbed image, and the output is the original image. Given that we're using the same network, there's nothing we need to change about the CAE class.
#
# TODO
# - However, add an argument called ```denoising``` (defaulted to be ```False```) in the train() to indicate if our input will be the noisy version (in this case ```denoising=True```) or a clean version (in this case ```denoising=False```), and modify the functions appropriately, with the following instructions. Do the same for validate() and evaluate() to decide if we want to validate/evaluate on noisy or clean images.
#
# - Perturbation (i.e., making images noisy)
#   - First make sure that each pixels are represented by a real number from -1 to 1 (instead of integers from 0 to 255). The pixel should be already from -1 to 1, unless you did something you shouldn't have done.
#   - Next, do a perturbation to each image where the noise is sampled according to the standard Gaussian distribution and then multiplied by a number uniformly sampled from 0 to 1.
#     - In other words, each pixel in image i should be perturbed with a noise (1) sampled from a standard Gaussian distribution and then (2) multiplied by $c_i$ for some $c_i \in (0,1)$, and each pixel in image j should be perturbed with a noise (1) sampled from a standard Gaussian distribution and then (2) multiplied by $c_j$ for some $c_j \in (0,1)$. (In fact, the result is that for each image, we're still sampling the noise from a Gaussian distribution; the mean is 0, and the standard deviation is sampled from a uniform distribution. Think: why?)
#     - Make sure that the resulting perturbed/noisy image are still represented by numbers from -1 to 1 (so you may need to do some clipping with min -1 and max 1).
#
# - To add noise to a batch of images, please use a helper function called add_noise(), outside the train(), validate(), evaluate() functions.

# %% [markdown]
# **Question 5: Training**
#
# Estimated debugging time: 30 min, or longer if you have more severe bugs.
#
# TODO
#
# - Now, train your CAE model (where your input is the original images), and train your denoising CAE model (where your input is the noisy images). You can set a patience counter on your own (similar to homework 2), meaning if validation loss doesn't decrease for, say, 10 epochs (just an example), then you can stop training. Each training procedure may take half an hour or an hour. It may take many many more hours if you didn't move the model or the data onto GPUs. Moreover, to make sure your training is not lost in case colab disconnects, it's important to save checkpoints! Make sure you wrote the checkpoint saving code in the validate function.
# - Report the best validation loss. No need to plot the curve, but you can plot it nevertheless to have a better understanding on your training process.
#
# Estimated training time in total: 2 hours (depending on your model)?
# - Please do not spend the 2 hours staring at your log.
# - You don't need to get the "best" model. You only need Question 6, Question 7, and Question 8 to work. Q6 works if your reconstructed images aren't bad (okay to be blurry); Q7 works if your plots looks similar to the presented; Q8 works if ...please read Q8.

# %%
batch_size = 64
best_val_loss = float('inf')
num_epoch = 100
learning_rate = 1e-3
log_interval = 100
weight_decay = 1e-3
denoising = False
keep_training_from_ckpt = False

if denoising:
    load_path = denoising_path
else:
    load_path = nondenoising_path

conv_autoencoder = CAE()
if cuda:
    conv_autoencoder.to(device)

if keep_training_from_ckpt:
    conv_autoencoder.load_state_dict(torch.load(load_path))
for epoch in range(num_epoch):
    start_time = datetime.datetime.now()
    train(conv_autoencoder, train_loader, epoch, num_epoch, learning_rate,
          weight_decay, log_interval, denoising)
    end_time = datetime.datetime.now()
    print(f'Trained this epoch using {(end_time - start_time).seconds} seconds')
    # validate and save model if it's the best model so far
    best_val_loss = validate(conv_autoencoder, valid_loader, best_val_loss,
                             denoising)
print('Training done; best validation loss {:.4f}'.format(best_val_loss))
# Out:
# Epoch [1/100] - Iter[100/937], MSE loss:113.243088
# Epoch [1/100] - Iter[200/937], MSE loss:75.943405
# Epoch [1/100] - Iter[300/937], MSE loss:72.491302
# Epoch [1/100] - Iter[400/937], MSE loss:67.443695
# Epoch [1/100] - Iter[500/937], MSE loss:63.636639
# Epoch [1/100] - Iter[600/937], MSE loss:55.549660
# Epoch [1/100] - Iter[700/937], MSE loss:52.872158
# Epoch [1/100] - Iter[800/937], MSE loss:51.471710
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 52.881931
# Saved best model in the checkpoint directory
#
# Epoch [2/100] - Iter[100/937], MSE loss:50.906555
# Epoch [2/100] - Iter[200/937], MSE loss:46.530769
# Epoch [2/100] - Iter[300/937], MSE loss:50.617512
# Epoch [2/100] - Iter[400/937], MSE loss:40.888130
# Epoch [2/100] - Iter[500/937], MSE loss:53.977074
# Epoch [2/100] - Iter[600/937], MSE loss:36.037773
# Epoch [2/100] - Iter[700/937], MSE loss:34.614922
# Epoch [2/100] - Iter[800/937], MSE loss:36.659096
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.091770
# Saved best model in the checkpoint directory
#
# Epoch [3/100] - Iter[100/937], MSE loss:36.979126
# Epoch [3/100] - Iter[200/937], MSE loss:41.080017
# Epoch [3/100] - Iter[300/937], MSE loss:41.162025
# Epoch [3/100] - Iter[400/937], MSE loss:30.853128
# Epoch [3/100] - Iter[500/937], MSE loss:35.819286
# Epoch [3/100] - Iter[600/937], MSE loss:32.553802
# Epoch [3/100] - Iter[700/937], MSE loss:31.331009
# Epoch [3/100] - Iter[800/937], MSE loss:28.475597
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 32.940781
# Saved best model in the checkpoint directory
#
# Epoch [4/100] - Iter[100/937], MSE loss:28.924473
# Epoch [4/100] - Iter[200/937], MSE loss:30.519650
# Epoch [4/100] - Iter[300/937], MSE loss:30.326075
# Epoch [4/100] - Iter[400/937], MSE loss:29.355297
# Epoch [4/100] - Iter[500/937], MSE loss:30.046888
# Epoch [4/100] - Iter[600/937], MSE loss:27.114338
# Epoch [4/100] - Iter[700/937], MSE loss:31.060207
# Epoch [4/100] - Iter[800/937], MSE loss:31.348637
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 28.047388
# Saved best model in the checkpoint directory
#
# Epoch [5/100] - Iter[100/937], MSE loss:30.041954
# Epoch [5/100] - Iter[200/937], MSE loss:27.677130
# Epoch [5/100] - Iter[300/937], MSE loss:27.557941
# Epoch [5/100] - Iter[400/937], MSE loss:25.924543
# Epoch [5/100] - Iter[500/937], MSE loss:30.861706
# Epoch [5/100] - Iter[600/937], MSE loss:27.932779
# Epoch [5/100] - Iter[700/937], MSE loss:28.622379
# Epoch [5/100] - Iter[800/937], MSE loss:30.952158
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 27.451101
# Saved best model in the checkpoint directory
#
# Epoch [6/100] - Iter[100/937], MSE loss:26.213432
# Epoch [6/100] - Iter[200/937], MSE loss:29.736986
# Epoch [6/100] - Iter[300/937], MSE loss:29.764931
# Epoch [6/100] - Iter[400/937], MSE loss:23.140608
# Epoch [6/100] - Iter[500/937], MSE loss:29.058105
# Epoch [6/100] - Iter[600/937], MSE loss:24.238106
# Epoch [6/100] - Iter[700/937], MSE loss:24.996376
# Epoch [6/100] - Iter[800/937], MSE loss:27.176302
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 25.853418
# Saved best model in the checkpoint directory
#
# Epoch [7/100] - Iter[100/937], MSE loss:25.219790
# Epoch [7/100] - Iter[200/937], MSE loss:24.896532
# Epoch [7/100] - Iter[300/937], MSE loss:23.904291
# Epoch [7/100] - Iter[400/937], MSE loss:24.312998
# Epoch [7/100] - Iter[500/937], MSE loss:24.336639
# Epoch [7/100] - Iter[600/937], MSE loss:27.164873
# Epoch [7/100] - Iter[700/937], MSE loss:26.013241
# Epoch [7/100] - Iter[800/937], MSE loss:26.104467
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 25.156240
# Saved best model in the checkpoint directory
#
# Epoch [8/100] - Iter[100/937], MSE loss:22.285629
# Epoch [8/100] - Iter[200/937], MSE loss:27.072868
# Epoch [8/100] - Iter[300/937], MSE loss:27.674538
# Epoch [8/100] - Iter[400/937], MSE loss:22.936951
# Epoch [8/100] - Iter[500/937], MSE loss:26.442234
# Epoch [8/100] - Iter[600/937], MSE loss:24.092607
# Epoch [8/100] - Iter[700/937], MSE loss:27.229845
# Epoch [8/100] - Iter[800/937], MSE loss:27.955545
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 24.565655
# Saved best model in the checkpoint directory
#
# Epoch [9/100] - Iter[100/937], MSE loss:22.101355
# Epoch [9/100] - Iter[200/937], MSE loss:25.054039
# Epoch [9/100] - Iter[300/937], MSE loss:25.018038
# Epoch [9/100] - Iter[400/937], MSE loss:30.395672
# Epoch [9/100] - Iter[500/937], MSE loss:30.109854
# Epoch [9/100] - Iter[600/937], MSE loss:26.395166
# Epoch [9/100] - Iter[700/937], MSE loss:26.319607
# Epoch [9/100] - Iter[800/937], MSE loss:28.846453
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 24.449135
# Saved best model in the checkpoint directory
#
# Epoch [10/100] - Iter[100/937], MSE loss:21.880890
# Epoch [10/100] - Iter[200/937], MSE loss:21.825438
# Epoch [10/100] - Iter[300/937], MSE loss:24.683718
# Epoch [10/100] - Iter[400/937], MSE loss:25.770641
# Epoch [10/100] - Iter[500/937], MSE loss:22.566383
# Epoch [10/100] - Iter[600/937], MSE loss:25.913254
# Epoch [10/100] - Iter[700/937], MSE loss:27.527702
# Epoch [10/100] - Iter[800/937], MSE loss:21.644760
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 24.281990
# Saved best model in the checkpoint directory
#
# Epoch [11/100] - Iter[100/937], MSE loss:24.610813
# Epoch [11/100] - Iter[200/937], MSE loss:24.620993
# Epoch [11/100] - Iter[300/937], MSE loss:24.247509
# Epoch [11/100] - Iter[400/937], MSE loss:21.950417
# Epoch [11/100] - Iter[500/937], MSE loss:26.582695
# Epoch [11/100] - Iter[600/937], MSE loss:22.168327
# Epoch [11/100] - Iter[700/937], MSE loss:26.462618
# Epoch [11/100] - Iter[800/937], MSE loss:28.228512
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 26.235653
# Epoch [12/100] - Iter[100/937], MSE loss:27.060993
# Epoch [12/100] - Iter[200/937], MSE loss:28.882812
# Epoch [12/100] - Iter[300/937], MSE loss:23.285725
# Epoch [12/100] - Iter[400/937], MSE loss:25.905470
# Epoch [12/100] - Iter[500/937], MSE loss:21.687782
# Epoch [12/100] - Iter[600/937], MSE loss:20.798630
# Epoch [12/100] - Iter[700/937], MSE loss:23.520426
# Epoch [12/100] - Iter[800/937], MSE loss:28.970881
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 23.091539
# Saved best model in the checkpoint directory
#
# Epoch [13/100] - Iter[100/937], MSE loss:20.406754
# Epoch [13/100] - Iter[200/937], MSE loss:22.891216
# Epoch [13/100] - Iter[300/937], MSE loss:23.574898
# Epoch [13/100] - Iter[400/937], MSE loss:25.217808
# Epoch [13/100] - Iter[500/937], MSE loss:22.529636
# Epoch [13/100] - Iter[600/937], MSE loss:24.134935
# Epoch [13/100] - Iter[700/937], MSE loss:22.731113
# Epoch [13/100] - Iter[800/937], MSE loss:21.780960
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 23.978186
# Epoch [14/100] - Iter[100/937], MSE loss:25.181843
# Epoch [14/100] - Iter[200/937], MSE loss:22.083450
# Epoch [14/100] - Iter[300/937], MSE loss:21.833214
# Epoch [14/100] - Iter[400/937], MSE loss:21.579126
# Epoch [14/100] - Iter[500/937], MSE loss:24.174847
# Epoch [14/100] - Iter[600/937], MSE loss:21.621460
# Epoch [14/100] - Iter[700/937], MSE loss:24.453190
# Epoch [14/100] - Iter[800/937], MSE loss:24.839432
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 22.938391
# Saved best model in the checkpoint directory
#
# Epoch [15/100] - Iter[100/937], MSE loss:25.334892
# Epoch [15/100] - Iter[200/937], MSE loss:28.729942
# Epoch [15/100] - Iter[300/937], MSE loss:24.288666
# Epoch [15/100] - Iter[400/937], MSE loss:21.542284
# Epoch [15/100] - Iter[500/937], MSE loss:20.422630
# Epoch [15/100] - Iter[600/937], MSE loss:21.867592
# Epoch [15/100] - Iter[700/937], MSE loss:23.315937
# Epoch [15/100] - Iter[800/937], MSE loss:23.018559
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 23.330070
# Epoch [16/100] - Iter[100/937], MSE loss:23.934937
# Epoch [16/100] - Iter[200/937], MSE loss:24.214592
# Epoch [16/100] - Iter[300/937], MSE loss:26.428843
# Epoch [16/100] - Iter[400/937], MSE loss:29.109009
# Epoch [16/100] - Iter[500/937], MSE loss:22.539444
# Epoch [16/100] - Iter[600/937], MSE loss:25.727186
# Epoch [16/100] - Iter[700/937], MSE loss:22.624454
# Epoch [16/100] - Iter[800/937], MSE loss:22.084162
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 22.449854
# Saved best model in the checkpoint directory
#
# Epoch [17/100] - Iter[100/937], MSE loss:21.807964
# Epoch [17/100] - Iter[200/937], MSE loss:23.312195
# Epoch [17/100] - Iter[300/937], MSE loss:21.940807
# Epoch [17/100] - Iter[400/937], MSE loss:23.385090
# Epoch [17/100] - Iter[500/937], MSE loss:20.318514
# Epoch [17/100] - Iter[600/937], MSE loss:22.690296
# Epoch [17/100] - Iter[700/937], MSE loss:20.165310
# Epoch [17/100] - Iter[800/937], MSE loss:24.340948
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 22.092066
# Saved best model in the checkpoint directory
#
# Epoch [18/100] - Iter[100/937], MSE loss:26.699795
# Epoch [18/100] - Iter[200/937], MSE loss:22.398415
# Epoch [18/100] - Iter[300/937], MSE loss:23.455322
# Epoch [18/100] - Iter[400/937], MSE loss:24.815905
# Epoch [18/100] - Iter[500/937], MSE loss:21.669582
# Epoch [18/100] - Iter[600/937], MSE loss:22.733135
# Epoch [18/100] - Iter[700/937], MSE loss:21.038074
# Epoch [18/100] - Iter[800/937], MSE loss:21.629059
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 21.877638
# Saved best model in the checkpoint directory
#
# Epoch [19/100] - Iter[100/937], MSE loss:21.077633
# Epoch [19/100] - Iter[200/937], MSE loss:24.930309
# Epoch [19/100] - Iter[300/937], MSE loss:24.408554
# Epoch [19/100] - Iter[400/937], MSE loss:23.942001
# Epoch [19/100] - Iter[500/937], MSE loss:20.198742
# Epoch [19/100] - Iter[600/937], MSE loss:20.896156
# Epoch [19/100] - Iter[700/937], MSE loss:21.520334
# Epoch [19/100] - Iter[800/937], MSE loss:20.024738
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 22.396927
# Epoch [20/100] - Iter[100/937], MSE loss:22.466709
# Epoch [20/100] - Iter[200/937], MSE loss:21.707165
# Epoch [20/100] - Iter[300/937], MSE loss:22.173925
# Epoch [20/100] - Iter[400/937], MSE loss:20.794392
# Epoch [20/100] - Iter[500/937], MSE loss:22.910000
# Epoch [20/100] - Iter[600/937], MSE loss:20.661863
# Epoch [20/100] - Iter[700/937], MSE loss:22.428898
# Epoch [20/100] - Iter[800/937], MSE loss:24.632690
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 22.589344
# Epoch [21/100] - Iter[100/937], MSE loss:20.952145
# Epoch [21/100] - Iter[200/937], MSE loss:19.700356
# Epoch [21/100] - Iter[300/937], MSE loss:20.804382
# Epoch [21/100] - Iter[400/937], MSE loss:20.578541
# Epoch [21/100] - Iter[500/937], MSE loss:24.962687
# Epoch [21/100] - Iter[600/937], MSE loss:25.187807
# Epoch [21/100] - Iter[700/937], MSE loss:22.534554
# Epoch [21/100] - Iter[800/937], MSE loss:27.873192
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 21.678690
# Saved best model in the checkpoint directory
#
# Epoch [22/100] - Iter[100/937], MSE loss:23.932783
# Epoch [22/100] - Iter[200/937], MSE loss:20.321548
# Epoch [22/100] - Iter[300/937], MSE loss:23.245255
# Epoch [22/100] - Iter[400/937], MSE loss:19.933147
# Epoch [22/100] - Iter[500/937], MSE loss:21.901649
# Epoch [22/100] - Iter[600/937], MSE loss:24.488544
# Epoch [22/100] - Iter[700/937], MSE loss:18.502792
# Epoch [22/100] - Iter[800/937], MSE loss:23.967045
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set:
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.629045
# Saved best model in the checkpoint directory
#
# Epoch [29/100] - Iter[100/937], MSE loss:22.053398
# Epoch [29/100] - Iter[200/937], MSE loss:22.179258
# Epoch [29/100] - Iter[300/937], MSE loss:20.324955
# Epoch [29/100] - Iter[400/937], MSE loss:19.705208
# Epoch [29/100] - Iter[500/937], MSE loss:21.318022
# Epoch [29/100] - Iter[600/937], MSE loss:22.561031
# Epoch [29/100] - Iter[700/937], MSE loss:19.526196
# Epoch [29/100] - Iter[800/937], MSE loss:20.757902
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.616589
# Saved best model in the checkpoint directory
#
# Epoch [30/100] - Iter[100/937], MSE loss:21.415848
# Epoch [30/100] - Iter[200/937], MSE loss:24.019810
# Epoch [30/100] - Iter[300/937], MSE loss:20.633972
# Epoch [30/100] - Iter[400/937], MSE loss:22.403973
# Epoch [30/100] - Iter[500/937], MSE loss:20.201935
# Epoch [30/100] - Iter[600/937], MSE loss:19.089346
# Epoch [30/100] - Iter[700/937], MSE loss:19.414051
# Epoch [30/100] - Iter[800/937], MSE loss:21.196802
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.568571
# Saved best model in the checkpoint directory
#
# Epoch [31/100] - Iter[100/937], MSE loss:20.401205
# Epoch [31/100] - Iter[200/937], MSE loss:21.801903
# Epoch [31/100] - Iter[300/937], MSE loss:21.181318
# Epoch [31/100] - Iter[400/937], MSE loss:22.501354
# Epoch [31/100] - Iter[500/937], MSE loss:21.481918
# Epoch [31/100] - Iter[600/937], MSE loss:19.024601
# Epoch [31/100] - Iter[700/937], MSE loss:21.364525
# Epoch [31/100] - Iter[800/937], MSE loss:22.355103
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.480831
# Saved best model in the checkpoint directory
#
# Epoch [32/100] - Iter[100/937], MSE loss:22.498709
# Epoch [32/100] - Iter[200/937], MSE loss:22.120293
# Epoch [32/100] - Iter[300/937], MSE loss:22.206488
# Epoch [32/100] - Iter[400/937], MSE loss:20.843426
# Epoch [32/100] - Iter[500/937], MSE loss:22.798466
# Epoch [32/100] - Iter[600/937], MSE loss:21.835396
# Epoch [32/100] - Iter[700/937], MSE loss:19.821217
# Epoch [32/100] - Iter[800/937], MSE loss:17.298082
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.462633
# Saved best model in the checkpoint directory
#
# Epoch [33/100] - Iter[100/937], MSE loss:18.518036
# Epoch [33/100] - Iter[200/937], MSE loss:19.818417
# Epoch [33/100] - Iter[300/937], MSE loss:21.510303
# Epoch [33/100] - Iter[400/937], MSE loss:20.939159
# Epoch [33/100] - Iter[500/937], MSE loss:22.757618
# Epoch [33/100] - Iter[600/937], MSE loss:20.873112
# Epoch [33/100] - Iter[700/937], MSE loss:19.439735
# Epoch [33/100] - Iter[800/937], MSE loss:24.030769
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.736778
# Epoch [34/100] - Iter[100/937], MSE loss:20.149242
# Epoch [34/100] - Iter[200/937], MSE loss:20.341677
# Epoch [34/100] - Iter[300/937], MSE loss:20.964443
# Epoch [34/100] - Iter[400/937], MSE loss:22.582542
# Epoch [34/100] - Iter[500/937], MSE loss:20.043756
# Epoch [34/100] - Iter[600/937], MSE loss:17.479914
# Epoch [34/100] - Iter[700/937], MSE loss:20.818438
# Epoch [34/100] - Iter[800/937], MSE loss:18.592052
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.037437
# Epoch [47/100] - Iter[100/937], MSE loss:18.609869
# Epoch [47/100] - Iter[200/937], MSE loss:19.712406
# Epoch [47/100] - Iter[300/937], MSE loss:19.505348
# Epoch [47/100] - Iter[400/937], MSE loss:22.399975
# Epoch [47/100] - Iter[500/937], MSE loss:20.590700
# Epoch [47/100] - Iter[600/937], MSE loss:20.001282
# Epoch [47/100] - Iter[700/937], MSE loss:19.278618
# Epoch [47/100] - Iter[800/937], MSE loss:20.373241
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.745016
# Saved best model in the checkpoint directory
#
# Epoch [48/100] - Iter[100/937], MSE loss:19.026360
# Epoch [48/100] - Iter[200/937], MSE loss:22.385479
# Epoch [48/100] - Iter[300/937], MSE loss:17.362305
# Epoch [48/100] - Iter[400/937], MSE loss:20.865543
# Epoch [48/100] - Iter[500/937], MSE loss:20.180050
# Epoch [48/100] - Iter[600/937], MSE loss:17.858280
# Epoch [48/100] - Iter[700/937], MSE loss:20.928646
# Epoch [48/100] - Iter[800/937], MSE loss:21.692127
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.824976
# Epoch [49/100] - Iter[100/937], MSE loss:23.308090
# Epoch [49/100] - Iter[200/937], MSE loss:22.038065
# Epoch [49/100] - Iter[300/937], MSE loss:16.284847
# Epoch [49/100] - Iter[400/937], MSE loss:20.571657
# Epoch [49/100] - Iter[500/937], MSE loss:19.901899
# Epoch [49/100] - Iter[600/937], MSE loss:22.882502
# Epoch [49/100] - Iter[700/937], MSE loss:19.239964
# Epoch [49/100] - Iter[800/937], MSE loss:21.378124
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.811714
# Epoch [50/100] - Iter[100/937], MSE loss:21.836580
# Epoch [50/100] - Iter[200/937], MSE loss:17.315804
# Epoch [50/100] - Iter[300/937], MSE loss:22.193878
# Epoch [50/100] - Iter[400/937], MSE loss:19.980370
# Epoch [50/100] - Iter[500/937], MSE loss:22.237827
# Epoch [50/100] - Iter[600/937], MSE loss:19.758808
# Epoch [50/100] - Iter[700/937], MSE loss:19.909590
# Epoch [50/100] - Iter[800/937], MSE loss:22.514832
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.304716
# Epoch [51/100] - Iter[100/937], MSE loss:25.604504
# Epoch [51/100] - Iter[200/937], MSE loss:17.159573
# Epoch [51/100] - Iter[300/937], MSE loss:17.909954
# Epoch [51/100] - Iter[400/937], MSE loss:20.405174
# Epoch [51/100] - Iter[500/937], MSE loss:21.081512
# Epoch [51/100] - Iter[600/937], MSE loss:23.044693
# Epoch [51/100] - Iter[700/937], MSE loss:22.303059
# Epoch [51/100] - Iter[800/937], MSE loss:20.752977
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.705954
# Saved best model in the checkpoint directory
#
# Epoch [52/100] - Iter[100/937], MSE loss:19.160378
# Epoch [52/100] - Iter[200/937], MSE loss:19.477884
# Epoch [52/100] - Iter[300/937], MSE loss:21.762976
# Epoch [52/100] - Iter[400/937], MSE loss:18.202740
# Epoch [52/100] - Iter[500/937], MSE loss:20.387264
# Epoch [52/100] - Iter[600/937], MSE loss:19.922661
# Epoch [52/100] - Iter[700/937], MSE loss:19.266644
# Epoch [52/100] - Iter[800/937], MSE loss:22.359474
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.701250
# Saved best model in the checkpoint directory
#
# Epoch [53/100] - Iter[100/937], MSE loss:17.857819
# Epoch [53/100] - Iter[200/937], MSE loss:18.823736
# Epoch [53/100] - Iter[300/937], MSE loss:21.227753
# Epoch [53/100] - Iter[400/937], MSE loss:18.900137
# Epoch [53/100] - Iter[500/937], MSE loss:19.691727
# Epoch [53/100] - Iter[600/937], MSE loss:23.196747
# Epoch [53/100] - Iter[700/937], MSE loss:20.968075
# Epoch [53/100] - Iter[800/937], MSE loss:21.489580
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.658415
# Saved best model in the checkpoint directory
#
# Epoch [54/100] - Iter[100/937], MSE loss:21.646915
# Epoch [54/100] - Iter[200/937], MSE loss:19.003887
# Epoch [54/100] - Iter[300/937], MSE loss:19.562441
# Epoch [54/100] - Iter[400/937], MSE loss:18.420616
# Epoch [54/100] - Iter[500/937], MSE loss:19.744621
# Epoch [54/100] - Iter[600/937], MSE loss:18.889126
# Epoch [54/100] - Iter[700/937], MSE loss:16.009260
# Epoch [54/100] - Iter[800/937], MSE loss:21.967638
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 20.076836
# Epoch [55/100] - Iter[100/937], MSE loss:18.301983
# Epoch [55/100] - Iter[200/937], MSE loss:19.822998
# Epoch [55/100] - Iter[300/937], MSE loss:21.524498
# Epoch [55/100] - Iter[400/937], MSE loss:21.700743
# Epoch [55/100] - Iter[500/937], MSE loss:21.984547
# Epoch [55/100] - Iter[600/937], MSE loss:20.061939
# Epoch [55/100] - Iter[700/937], MSE loss:19.233551
# Epoch [55/100] - Iter[800/937], MSE loss:19.442471
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.721447
# Epoch [56/100] - Iter[100/937], MSE loss:18.223837
# Epoch [56/100] - Iter[200/937], MSE loss:20.294697
# Epoch [56/100] - Iter[300/937], MSE loss:19.607540
# Epoch [56/100] - Iter[400/937], MSE loss:19.871326
# Epoch [56/100] - Iter[500/937], MSE loss:18.370003
# Epoch [56/100] - Iter[600/937], MSE loss:18.635620
# Epoch [56/100] - Iter[700/937], MSE loss:18.530933
# Epoch [56/100] - Iter[800/937], MSE loss:21.095734
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.743158
# Epoch [57/100] - Iter[100/937], MSE loss:20.828804
# Epoch [57/100] - Iter[200/937], MSE loss:16.909849
# Epoch [57/100] - Iter[300/937], MSE loss:17.900902
# Epoch [57/100] - Iter[400/937], MSE loss:19.527914
# Epoch [57/100] - Iter[500/937], MSE loss:19.110386
# Epoch [57/100] - Iter[600/937], MSE loss:16.977982
# Epoch [57/100] - Iter[700/937], MSE loss:21.344688
# Epoch [57/100] - Iter[800/937], MSE loss:19.390858
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.475597
# Saved best model in the checkpoint directory
#
# Epoch [58/100] - Iter[100/937], MSE loss:20.536125
# Epoch [58/100] - Iter[200/937], MSE loss:20.964230
# Epoch [58/100] - Iter[300/937], MSE loss:20.371901
# Epoch [58/100] - Iter[400/937], MSE loss:20.049488
# Epoch [58/100] - Iter[500/937], MSE loss:20.091675
# Epoch [58/100] - Iter[600/937], MSE loss:19.596544
# Epoch [58/100] - Iter[700/937], MSE loss:21.747482
# Epoch [58/100] - Iter[800/937], MSE loss:20.355333
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 18.940075
# Epoch [95/100] - Iter[100/937], MSE loss:20.723343
# Epoch [95/100] - Iter[200/937], MSE loss:18.432625
# Epoch [95/100] - Iter[300/937], MSE loss:18.467777
# Epoch [95/100] - Iter[400/937], MSE loss:19.833138
# Epoch [95/100] - Iter[500/937], MSE loss:18.517483
# Epoch [95/100] - Iter[600/937], MSE loss:18.924404
# Epoch [95/100] - Iter[700/937], MSE loss:19.599173
# Epoch [95/100] - Iter[800/937], MSE loss:20.073568
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 18.758118
# Saved best model in the checkpoint directory
#
# Epoch [96/100] - Iter[100/937], MSE loss:21.454311
# Epoch [96/100] - Iter[200/937], MSE loss:17.027962
# Epoch [96/100] - Iter[300/937], MSE loss:21.788836
# Epoch [96/100] - Iter[400/937], MSE loss:19.762482
# Epoch [96/100] - Iter[500/937], MSE loss:15.072655
# Epoch [96/100] - Iter[600/937], MSE loss:17.725471
# Epoch [96/100] - Iter[700/937], MSE loss:19.327570
# Epoch [96/100] - Iter[800/937], MSE loss:19.403015
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 18.723892
# Saved best model in the checkpoint directory
#
# Epoch [97/100] - Iter[100/937], MSE loss:19.654757
# Epoch [97/100] - Iter[200/937], MSE loss:19.473043
# Epoch [97/100] - Iter[300/937], MSE loss:17.488997
# Epoch [97/100] - Iter[400/937], MSE loss:21.283113
# Epoch [97/100] - Iter[500/937], MSE loss:17.775173
# Epoch [97/100] - Iter[600/937], MSE loss:17.133631
# Epoch [97/100] - Iter[700/937], MSE loss:17.972128
# Epoch [97/100] - Iter[800/937], MSE loss:19.782658
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.156071
# Epoch [98/100] - Iter[100/937], MSE loss:18.521477
# Epoch [98/100] - Iter[200/937], MSE loss:21.055353
# Epoch [98/100] - Iter[300/937], MSE loss:20.501034
# Epoch [98/100] - Iter[400/937], MSE loss:19.005207
# Epoch [98/100] - Iter[500/937], MSE loss:19.571901
# Epoch [98/100] - Iter[600/937], MSE loss:21.622189
# Epoch [98/100] - Iter[700/937], MSE loss:17.748791
# Epoch [98/100] - Iter[800/937], MSE loss:18.084106
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 18.908667
# Epoch [99/100] - Iter[100/937], MSE loss:19.425835
# Epoch [99/100] - Iter[200/937], MSE loss:18.895908
# Epoch [99/100] - Iter[300/937], MSE loss:20.496136
# Epoch [99/100] - Iter[400/937], MSE loss:17.345442
# Epoch [99/100] - Iter[500/937], MSE loss:20.827753
# Epoch [99/100] - Iter[600/937], MSE loss:17.287970
# Epoch [99/100] - Iter[700/937], MSE loss:17.691223
# Epoch [99/100] - Iter[800/937], MSE loss:17.641775
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 18.741177
# Epoch [100/100] - Iter[100/937], MSE loss:19.535416
# Epoch [100/100] - Iter[200/937], MSE loss:18.970264
# Epoch [100/100] - Iter[300/937], MSE loss:20.601482
# Epoch [100/100] - Iter[400/937], MSE loss:19.298115
# Epoch [100/100] - Iter[500/937], MSE loss:20.262163
# Epoch [100/100] - Iter[600/937], MSE loss:16.954632
# Epoch [100/100] - Iter[700/937], MSE loss:19.258955
# Epoch [100/100] - Iter[800/937], MSE loss:19.696802
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 19.330591
# Training done; best validation loss 18.7239

# %% [markdown]
# ## See above lines for best performance on noising model

# %%
batch_size = 64
best_val_loss = float('inf')
num_epoch = 100
learning_rate = 1e-3
log_interval = 100
weight_decay = 1e-3
denoising = True
keep_training_from_ckpt = False

if denoising:
    load_path = denoising_path
else:
    load_path = nondenoising_path

conv_autoencoder = CAE()
if cuda:
    conv_autoencoder.to(device)

if keep_training_from_ckpt:
    conv_autoencoder.load_state_dict(torch.load(load_path))
for epoch in range(num_epoch):
    start_time = datetime.datetime.now()
    train(conv_autoencoder, train_loader, epoch, num_epoch, learning_rate,
          weight_decay, log_interval, denoising)
    
    end_time = datetime.datetime.now()
    print(f'Trained this epoch using {(end_time - start_time).seconds} seconds')
    # validate and save model if it's the best model so far
    best_val_loss = validate(conv_autoencoder, valid_loader, best_val_loss,
                             denoising)
print('Training done; best validation loss {:.4f}'.format(best_val_loss))
# Out:
# Epoch [1/100] - Iter[100/937], MSE loss:137.170242
# Epoch [1/100] - Iter[200/937], MSE loss:108.273163
# Epoch [1/100] - Iter[300/937], MSE loss:86.688072
# Epoch [1/100] - Iter[400/937], MSE loss:86.024063
# Epoch [1/100] - Iter[500/937], MSE loss:77.419891
# Epoch [1/100] - Iter[600/937], MSE loss:74.126175
# Epoch [1/100] - Iter[700/937], MSE loss:69.967583
# Epoch [1/100] - Iter[800/937], MSE loss:74.239456
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 70.157112
# Saved best model in the checkpoint directory
#
# Epoch [2/100] - Iter[100/937], MSE loss:61.391052
# Epoch [2/100] - Iter[200/937], MSE loss:61.398743
# Epoch [2/100] - Iter[300/937], MSE loss:49.928982
# Epoch [2/100] - Iter[400/937], MSE loss:54.951401
# Epoch [2/100] - Iter[500/937], MSE loss:53.566349
# Epoch [2/100] - Iter[600/937], MSE loss:52.943157
# Epoch [2/100] - Iter[700/937], MSE loss:49.740250
# Epoch [2/100] - Iter[800/937], MSE loss:51.488525
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 48.884193
# Saved best model in the checkpoint directory
#
# Epoch [3/100] - Iter[100/937], MSE loss:48.876312
# Epoch [3/100] - Iter[200/937], MSE loss:48.947041
# Epoch [3/100] - Iter[300/937], MSE loss:44.094139
# Epoch [3/100] - Iter[400/937], MSE loss:48.147903
# Epoch [3/100] - Iter[500/937], MSE loss:46.550186
# Epoch [3/100] - Iter[600/937], MSE loss:47.482056
# Epoch [3/100] - Iter[700/937], MSE loss:42.211845
# Epoch [3/100] - Iter[800/937], MSE loss:41.158287
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 46.101959
# Saved best model in the checkpoint directory
#
# Epoch [4/100] - Iter[100/937], MSE loss:41.017128
# Epoch [4/100] - Iter[200/937], MSE loss:58.480522
# Epoch [4/100] - Iter[300/937], MSE loss:43.713734
# Epoch [4/100] - Iter[400/937], MSE loss:43.875614
# Epoch [4/100] - Iter[500/937], MSE loss:40.716511
# Epoch [4/100] - Iter[600/937], MSE loss:48.752678
# Epoch [4/100] - Iter[700/937], MSE loss:45.833462
# Epoch [4/100] - Iter[800/937], MSE loss:42.346073
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 41.352306
# Saved best model in the checkpoint directory
#
# Epoch [5/100] - Iter[100/937], MSE loss:44.628056
# Epoch [5/100] - Iter[200/937], MSE loss:42.522049
# Epoch [5/100] - Iter[300/937], MSE loss:39.898991
# Epoch [5/100] - Iter[400/937], MSE loss:41.427780
# Epoch [5/100] - Iter[500/937], MSE loss:45.443687
# Epoch [5/100] - Iter[600/937], MSE loss:43.481361
# Epoch [5/100] - Iter[700/937], MSE loss:39.095917
# Epoch [5/100] - Iter[800/937], MSE loss:39.434494
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 41.195808
# Saved best model in the checkpoint directory
#
# Epoch [6/100] - Iter[100/937], MSE loss:42.214233
# Epoch [6/100] - Iter[200/937], MSE loss:43.496269
# Epoch [6/100] - Iter[300/937], MSE loss:38.947414
# Epoch [6/100] - Iter[400/937], MSE loss:41.678665
# Epoch [6/100] - Iter[500/937], MSE loss:43.011528
# Epoch [6/100] - Iter[600/937], MSE loss:40.610397
# Epoch [6/100] - Iter[700/937], MSE loss:40.862747
# Epoch [6/100] - Iter[800/937], MSE loss:41.642624
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 39.746784
# Saved best model in the checkpoint directory
#
# Epoch [7/100] - Iter[100/937], MSE loss:46.405220
# Epoch [7/100] - Iter[200/937], MSE loss:38.385361
# Epoch [7/100] - Iter[300/937], MSE loss:42.877941
# Epoch [7/100] - Iter[400/937], MSE loss:37.375839
# Epoch [7/100] - Iter[500/937], MSE loss:38.044025
# Epoch [7/100] - Iter[600/937], MSE loss:38.306938
# Epoch [7/100] - Iter[700/937], MSE loss:43.122272
# Epoch [7/100] - Iter[800/937], MSE loss:42.275032
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 39.300056
# Saved best model in the checkpoint directory
#
# Epoch [8/100] - Iter[100/937], MSE loss:38.954788
# Epoch [8/100] - Iter[200/937], MSE loss:34.732010
# Epoch [8/100] - Iter[300/937], MSE loss:43.542305
# Epoch [8/100] - Iter[400/937], MSE loss:41.693222
# Epoch [8/100] - Iter[500/937], MSE loss:40.629444
# Epoch [8/100] - Iter[600/937], MSE loss:42.076897
# Epoch [8/100] - Iter[700/937], MSE loss:37.393887
# Epoch [8/100] - Iter[800/937], MSE loss:47.968678
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 40.629875
# Epoch [9/100] - Iter[100/937], MSE loss:43.705425
# Epoch [9/100] - Iter[200/937], MSE loss:45.733383
# Epoch [9/100] - Iter[300/937], MSE loss:38.862556
# Epoch [9/100] - Iter[400/937], MSE loss:41.748283
# Epoch [9/100] - Iter[500/937], MSE loss:36.769150
# Epoch [9/100] - Iter[600/937], MSE loss:43.621655
# Epoch [9/100] - Iter[700/937], MSE loss:38.308990
# Epoch [9/100] - Iter[800/937], MSE loss:44.150482
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 38.682163
# Saved best model in the checkpoint directory
#
# Epoch [10/100] - Iter[100/937], MSE loss:44.796047
# Epoch [10/100] - Iter[200/937], MSE loss:38.845135
# Epoch [10/100] - Iter[300/937], MSE loss:34.669312
# Epoch [10/100] - Iter[400/937], MSE loss:39.842281
# Epoch [10/100] - Iter[500/937], MSE loss:35.433815
# Epoch [10/100] - Iter[600/937], MSE loss:40.345474
# Epoch [10/100] - Iter[700/937], MSE loss:41.991936
# Epoch [10/100] - Iter[800/937], MSE loss:39.639771
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 38.255268
# Saved best model in the checkpoint directory
#
# Epoch [11/100] - Iter[100/937], MSE loss:39.390038
# Epoch [11/100] - Iter[200/937], MSE loss:37.677551
# Epoch [11/100] - Iter[300/937], MSE loss:47.941330
# Epoch [11/100] - Iter[400/937], MSE loss:41.748810
# Epoch [11/100] - Iter[500/937], MSE loss:35.532181
# Epoch [11/100] - Iter[600/937], MSE loss:36.898605
# Epoch [11/100] - Iter[700/937], MSE loss:35.952408
# Epoch [11/100] - Iter[800/937], MSE loss:38.736809
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 38.068573
# Saved best model in the checkpoint directory
#
# Epoch [12/100] - Iter[100/937], MSE loss:45.180725
# Epoch [12/100] - Iter[200/937], MSE loss:40.166664
# Epoch [12/100] - Iter[300/937], MSE loss:38.403851
# Epoch [12/100] - Iter[400/937], MSE loss:36.697823
# Epoch [12/100] - Iter[500/937], MSE loss:34.231518
# Epoch [12/100] - Iter[600/937], MSE loss:40.658089
# Epoch [12/100] - Iter[700/937], MSE loss:38.963737
# Epoch [12/100] - Iter[800/937], MSE loss:36.385994
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set:
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 35.378635
# Saved best model in the checkpoint directory
#
# Epoch [43/100] - Iter[100/937], MSE loss:38.678650
# Epoch [43/100] - Iter[200/937], MSE loss:42.379425
# Epoch [43/100] - Iter[300/937], MSE loss:40.254707
# Epoch [43/100] - Iter[400/937], MSE loss:38.154812
# Epoch [43/100] - Iter[500/937], MSE loss:37.775696
# Epoch [43/100] - Iter[600/937], MSE loss:36.811230
# Epoch [43/100] - Iter[700/937], MSE loss:33.752304
# Epoch [43/100] - Iter[800/937], MSE loss:37.470100
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 35.265095
# Saved best model in the checkpoint directory
#
# Epoch [44/100] - Iter[100/937], MSE loss:33.452950
# Epoch [44/100] - Iter[200/937], MSE loss:32.441593
# Epoch [44/100] - Iter[300/937], MSE loss:38.567986
# Epoch [44/100] - Iter[400/937], MSE loss:38.597206
# Epoch [44/100] - Iter[500/937], MSE loss:36.463055
# Epoch [44/100] - Iter[600/937], MSE loss:38.104935
# Epoch [44/100] - Iter[700/937], MSE loss:34.192604
# Epoch [44/100] - Iter[800/937], MSE loss:33.902718
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 35.725052
# Epoch [45/100] - Iter[100/937], MSE loss:40.599789
# Epoch [45/100] - Iter[200/937], MSE loss:36.940262
# Epoch [45/100] - Iter[300/937], MSE loss:32.966759
# Epoch [45/100] - Iter[400/937], MSE loss:42.895931
# Epoch [45/100] - Iter[500/937], MSE loss:38.676544
# Epoch [45/100] - Iter[600/937], MSE loss:33.335037
# Epoch [45/100] - Iter[700/937], MSE loss:36.328026
# Epoch [45/100] - Iter[800/937], MSE loss:36.354736
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 35.166679
# Saved best model in the checkpoint directory
#
# Epoch [46/100] - Iter[100/937], MSE loss:35.557228
# Epoch [46/100] - Iter[200/937], MSE loss:34.939796
# Epoch [46/100] - Iter[300/937], MSE loss:34.885094
# Epoch [46/100] - Iter[400/937], MSE loss:38.362320
# Epoch [46/100] - Iter[500/937], MSE loss:33.628578
# Epoch [46/100] - Iter[600/937], MSE loss:36.604980
# Epoch [46/100] - Iter[700/937], MSE loss:33.101097
# Epoch [46/100] - Iter[800/937], MSE loss:33.924511
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 35.351368
# Epoch [47/100] - Iter[100/937], MSE loss:33.071243
# Epoch [47/100] - Iter[200/937], MSE loss:35.586693
# Epoch [47/100] - Iter[300/937], MSE loss:36.145805
# Epoch [47/100] - Iter[400/937], MSE loss:34.389084
# Epoch [47/100] - Iter[500/937], MSE loss:33.557762
# Epoch [47/100] - Iter[600/937], MSE loss:36.877235
# Epoch [47/100] - Iter[700/937], MSE loss:32.949654
# Epoch [47/100] - Iter[800/937], MSE loss:32.564938
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 35.868896
# Epoch [48/100] - Iter[100/937], MSE loss:36.167015
# Epoch [48/100] - Iter[200/937], MSE loss:37.440128
# Epoch [48/100] - Iter[300/937], MSE loss:37.456295
# Epoch [48/100] - Iter[400/937], MSE loss:36.761368
# Epoch [48/100] - Iter[500/937], MSE loss:35.107162
# Epoch [48/100] - Iter[600/937], MSE loss:36.977089
# Epoch [48/100] - Iter[700/937], MSE loss:37.204762
# Epoch [48/100] - Iter[800/937], MSE loss:35.024033
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 35
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.872372
# Epoch [79/100] - Iter[100/937], MSE loss:37.843155
# Epoch [79/100] - Iter[200/937], MSE loss:32.916775
# Epoch [79/100] - Iter[300/937], MSE loss:37.097767
# Epoch [79/100] - Iter[400/937], MSE loss:37.117821
# Epoch [79/100] - Iter[500/937], MSE loss:33.309616
# Epoch [79/100] - Iter[600/937], MSE loss:32.925316
# Epoch [79/100] - Iter[700/937], MSE loss:34.658920
# Epoch [79/100] - Iter[800/937], MSE loss:32.885204
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 34.530128
# Saved best model in the checkpoint directory
#
# Epoch [80/100] - Iter[100/937], MSE loss:34.503601
# Epoch [80/100] - Iter[200/937], MSE loss:34.367451
# Epoch [80/100] - Iter[300/937], MSE loss:34.699131
# Epoch [80/100] - Iter[400/937], MSE loss:34.943413
# Epoch [80/100] - Iter[500/937], MSE loss:36.548271
# Epoch [80/100] - Iter[600/937], MSE loss:38.740623
# Epoch [80/100] - Iter[700/937], MSE loss:37.605625
# Epoch [80/100] - Iter[800/937], MSE loss:36.514061
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.912518
# Epoch [81/100] - Iter[100/937], MSE loss:35.613800
# Epoch [81/100] - Iter[200/937], MSE loss:34.584324
# Epoch [81/100] - Iter[300/937], MSE loss:35.722660
# Epoch [81/100] - Iter[400/937], MSE loss:34.426521
# Epoch [81/100] - Iter[500/937], MSE loss:35.434818
# Epoch [81/100] - Iter[600/937], MSE loss:39.128738
# Epoch [81/100] - Iter[700/937], MSE loss:35.645695
# Epoch [81/100] - Iter[800/937], MSE loss:38.325874
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.854656
# Epoch [82/100] - Iter[100/937], MSE loss:34.962677
# Epoch [82/100] - Iter[200/937], MSE loss:37.121433
# Epoch [82/100] - Iter[300/937], MSE loss:38.032944
# Epoch [82/100] - Iter[400/937], MSE loss:35.054955
# Epoch [82/100] - Iter[500/937], MSE loss:37.842499
# Epoch [82/100] - Iter[600/937], MSE loss:34.605667
# Epoch [82/100] - Iter[700/937], MSE loss:36.163628
# Epoch [82/100] - Iter[800/937], MSE loss:35.473419
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.506340
# Saved best model in the checkpoint directory
#
# Epoch [83/100] - Iter[100/937], MSE loss:38.145927
# Epoch [83/100] - Iter[200/937], MSE loss:37.825718
# Epoch [83/100] - Iter[300/937], MSE loss:33.480301
# Epoch [83/100] - Iter[400/937], MSE loss:36.496521
# Epoch [83/100] - Iter[500/937], MSE loss:33.645412
# Epoch [83/100] - Iter[600/937], MSE loss:38.318802
# Epoch [83/100] - Iter[700/937], MSE loss:31.755102
# Epoch [83/100] - Iter[800/937], MSE loss:37.514439
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.487274
# Saved best model in the checkpoint directory
#
# Epoch [84/100] - Iter[100/937], MSE loss:33.751820
# Epoch [84/100] - Iter[200/937], MSE loss:38.771584
# Epoch [84/100] - Iter[300/937], MSE loss:40.578655
# Epoch [84/100] - Iter[400/937], MSE loss:34.212379
# Epoch [84/100] - Iter[500/937], MSE loss:31.403967
# Epoch [84/100] - Iter[600/937], MSE loss:31.841803
# Epoch [84/100] - Iter[700/937], MSE loss:35.568794
# Epoch [84/100] - Iter[800/937], MSE loss:30.804214
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 35
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.553562
# Epoch [92/100] - Iter[100/937], MSE loss:31.767189
# Epoch [92/100] - Iter[200/937], MSE loss:39.095535
# Epoch [92/100] - Iter[300/937], MSE loss:30.792351
# Epoch [92/100] - Iter[400/937], MSE loss:34.086487
# Epoch [92/100] - Iter[500/937], MSE loss:34.979298
# Epoch [92/100] - Iter[600/937], MSE loss:31.419231
# Epoch [92/100] - Iter[700/937], MSE loss:32.233536
# Epoch [92/100] - Iter[800/937], MSE loss:33.785934
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.914818
# Epoch [93/100] - Iter[100/937], MSE loss:31.801254
# Epoch [93/100] - Iter[200/937], MSE loss:34.940422
# Epoch [93/100] - Iter[300/937], MSE loss:31.639683
# Epoch [93/100] - Iter[400/937], MSE loss:35.638596
# Epoch [93/100] - Iter[500/937], MSE loss:35.954544
# Epoch [93/100] - Iter[600/937], MSE loss:33.371201
# Epoch [93/100] - Iter[700/937], MSE loss:36.138817
# Epoch [93/100] - Iter[800/937], MSE loss:31.818150
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.273739
# Saved best model in the checkpoint directory
#
# Epoch [94/100] - Iter[100/937], MSE loss:37.045349
# Epoch [94/100] - Iter[200/937], MSE loss:35.618172
# Epoch [94/100] - Iter[300/937], MSE loss:37.011765
# Epoch [94/100] - Iter[400/937], MSE loss:33.551186
# Epoch [94/100] - Iter[500/937], MSE loss:35.426140
# Epoch [94/100] - Iter[600/937], MSE loss:34.821003
# Epoch [94/100] - Iter[700/937], MSE loss:45.700668
# Epoch [94/100] - Iter[800/937], MSE loss:35.185532
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 35.042244
# Epoch [95/100] - Iter[100/937], MSE loss:36.510872
# Epoch [95/100] - Iter[200/937], MSE loss:33.824631
# Epoch [95/100] - Iter[300/937], MSE loss:34.586853
# Epoch [95/100] - Iter[400/937], MSE loss:33.881348
# Epoch [95/100] - Iter[500/937], MSE loss:35.202412
# Epoch [95/100] - Iter[600/937], MSE loss:34.965172
# Epoch [95/100] - Iter[700/937], MSE loss:36.779472
# Epoch [95/100] - Iter[800/937], MSE loss:37.069958
# Trained this epoch using 10 seconds
#
# Loss per batch on validation set: 34.497482
# Epoch [96/100] - Iter[100/937], MSE loss:34.418938
# Epoch [96/100] - Iter[200/937], MSE loss:35.170643
# Epoch [96/100] - Iter[300/937], MSE loss:33.166977
# Epoch [96/100] - Iter[400/937], MSE loss:31.196087
# Epoch [96/100] - Iter[500/937], MSE loss:36.010609
# Epoch [96/100] - Iter[600/937], MSE loss:32.209053
# Epoch [96/100] - Iter[700/937], MSE loss:31.892126
# Epoch [96/100] - Iter[800/937], MSE loss:35.072807
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 35.083366
# Epoch [97/100] - Iter[100/937], MSE loss:39.933311
# Epoch [97/100] - Iter[200/937], MSE loss:36.648411
# Epoch [97/100] - Iter[300/937], MSE loss:32.711517
# Epoch [97/100] - Iter[400/937], MSE loss:35.306969
# Epoch [97/100] - Iter[500/937], MSE loss:32.730942
# Epoch [97/100] - Iter[600/937], MSE loss:38.285709
# Epoch [97/100] - Iter[700/937], MSE loss:32.933018
# Epoch [97/100] - Iter[800/937], MSE loss:35.671989
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.517101
# Epoch [98/100] - Iter[100/937], MSE loss:33.037128
# Epoch [98/100] - Iter[200/937], MSE loss:33.234627
# Epoch [98/100] - Iter[300/937], MSE loss:33.386799
# Epoch [98/100] - Iter[400/937], MSE loss:33.455265
# Epoch [98/100] - Iter[500/937], MSE loss:38.603470
# Epoch [98/100] - Iter[600/937], MSE loss:35.739647
# Epoch [98/100] - Iter[700/937], MSE loss:33.183754
# Epoch [98/100] - Iter[800/937], MSE loss:29.903048
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.660614
# Epoch [99/100] - Iter[100/937], MSE loss:34.749325
# Epoch [99/100] - Iter[200/937], MSE loss:33.413864
# Epoch [99/100] - Iter[300/937], MSE loss:40.012093
# Epoch [99/100] - Iter[400/937], MSE loss:37.839836
# Epoch [99/100] - Iter[500/937], MSE loss:33.785217
# Epoch [99/100] - Iter[600/937], MSE loss:33.757065
# Epoch [99/100] - Iter[700/937], MSE loss:35.183380
# Epoch [99/100] - Iter[800/937], MSE loss:33.980785
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.410866
# Epoch [100/100] - Iter[100/937], MSE loss:32.068581
# Epoch [100/100] - Iter[200/937], MSE loss:36.408150
# Epoch [100/100] - Iter[300/937], MSE loss:33.764271
# Epoch [100/100] - Iter[400/937], MSE loss:33.165382
# Epoch [100/100] - Iter[500/937], MSE loss:35.214218
# Epoch [100/100] - Iter[600/937], MSE loss:36.417801
# Epoch [100/100] - Iter[700/937], MSE loss:34.776733
# Epoch [100/100] - Iter[800/937], MSE loss:36.996212
# Trained this epoch using 11 seconds
#
# Loss per batch on validation set: 34.201981
# Saved best model in the checkpoint directory
#
# Training done; best validation loss 34.2020

# %% [markdown]
# ## See above lines for best performance on non-denoising model

# %% [markdown]
# **Question 6: evaluate on test sets**
#
# Estimated time: 10 min.
#
# Only run the below cell when you're done with training, and you're evaluating on test sets.
#
# TODO:
# - Print out the reconstruction loss on test set for both the CAE and denoising CAE models.
# - Print out a few reconstructed images (for both models). Here, the input to CAE should be clean images; the input to denoising CAE should be noisy images. It's perfectly fine if your reconstructed images are blurry. If your reconstructed image is extremely bad (for example, if you absolutely can't tell what object it is anymore), then you probably made a mistake in the previous steps. You might have chosen an overly small out_channel, for example. Or, learning might be inadequate. Or, you made a mistake in model saving / model loading.

# %%
# Only run at evaluation time!

def print_loss_and_reconstructed_images(denoising):
    if denoising:
        conv_autoencoder.load_state_dict(torch.load(denoising_path)['model'])
    else:
        conv_autoencoder.load_state_dict(torch.load(nondenoising_path)['model'])
    if cuda:
        conv_autoencoder.cuda()
    # TODO: evaluate on test set and print out reconstruction loss
    evaluate(conv_autoencoder, test_loader, denoising=denoising)
    conv_autoencoder.cpu()
    dataiter = iter(test_loader)
    images, _ = next(dataiter)
    images = images[:32]
    if denoising:
        images_noisy = add_noise(images)
    else:
        images_noisy = images
    outputs = conv_autoencoder(images_noisy)

    plt.figure()
    imshow(torchvision.utils.make_grid(images_noisy.data))
    plt.figure()
    imshow(torchvision.utils.make_grid(outputs.data))

# %%
print_loss_and_reconstructed_images(denoising=True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# MSE loss per batch on test set: 34.471474

# %%
print_loss_and_reconstructed_images(denoising=False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# MSE loss per batch on test set: 18.771606

# %% [markdown]
# ### Plotting loss vs. noise length

# %% [markdown]
# **Question 7: plot loss vs. noise length**
#
# Estimated time: 30 min.
#
# TODO:
# For both CAE and denoising CAE models you trained, plot loss vs. noise length, for five different images in five separate plots.
# - Terminology
#   - The noise length is the L2 norm of the noise you added to the image. So, it will be the norm of image_noisy minus image.
#   - The loss refers to the reconstruction loss.
#
# - For each image...
#   - **In this part, the input to both CAE and denoising CAE should be noisy images.** But how much noise?
#   - For each image, at least add 100 different noises with different length (so we're doing at least 100 "trials"). Perhaps you can use different standard deviations in the Gaussian distribution (when you add the noise into the images). For example, you can refer to the provided add_noise_coeff function with coeff as an input argument. You don't need to use this function.
#   - Compute the reconstruction loss for each noise you added.
#   - Now you would have the following list [(noise length #1, loss #1), (noise length #2, loss #2), ..., (noise length #n, loss #n)] (where n is at least 100) for CAE. You should have a similar list for denoising CAE. Now plot the loss (vertical axis) and length (horizontal axis), of two models, in the same plot. But note that the plot only corresponds to one original clean image.
#
# - Do the above for 3 different images.
#
# - Feel free to use get_length_and_loss as a template. However, absolutely no need to follow the logic of get_length_and_loss.
#
# - For each image, you should see a plot similar to the below trend. Think: why? No need to explain.

# %%
def add_noise_coeff(images, coeff):
    noise = torch.mul(
        torch.randn(images.shape),
        torch.tensor([coeff]).view(-1, 1, 1, 1))
    images_noisy = images + noise
    images_noisy = torch.clamp(images_noisy, -1.0, 1.0)
    return images_noisy

# %%
dataiter = iter(test_loader)
images, _ = next(dataiter)
trial_image = images[:1]

# %%
# Plot loss vs. length

denoising = False

loss_cae = []
length_cae = []
loss_dcae = []
length_dcae = []

def get_length_and_loss(denoising, n):
    loss_ae = []
    length_ae = []
    autoencoder = CAE()

    if denoising:
        autoencoder.load_state_dict(torch.load(denoising_path)['model'])
    else:
        autoencoder.load_state_dict(torch.load(nondenoising_path)['model'])

    total_loss = 0
    criteria = nn.MSELoss(reduction='mean')
    autoencoder.eval()

    losses_ae = []
    lengths_ae = []
    losses = []
    for i, data in enumerate(test_loader):
        if i >= n:
           break
        images, _ = data
        coefficient = 0.0
        while coefficient < 1.5:
            images_noisy = add_noise_coeff(trial_image, coefficient)
            length_ae.append(torch.norm(images_noisy- trial_image))
            outputs = autoencoder(images_noisy)
            loss = criteria(outputs, trial_image)
            loss_ae.append(loss.item())
            coefficient += 0.01
        losses.append(loss)
        losses_ae.append(loss_ae)
        lengths_ae.append(length_ae)
    return losses_ae, lengths_ae

# %%
n = 4
losses_c, lengths_c = get_length_and_loss(False, n)
losses_dc, lengths_dc = get_length_and_loss(True, n)

for i in range(n):
    loss_c = [float(x) for x in losses_c[i]]
    length_c = [float(x) for x in lengths_c[i]]
    loss_dc = [float(x) for x in losses_dc[i]]
    length_dc = [float(x) for x in lengths_dc[i]] 
    plt.figure(figsize=(20,10))
    plt.scatter(length_c, loss_c, label='Standard CAE')
    plt.scatter(length_dc, loss_dc, label='Denoising CAE')
    plt.xlabel('Length')
    plt.ylabel('Loss')
    plt.legend()
    plt.title("{}".format(i))

# %% [markdown]
# ### Visualizing interpolation

# %% [markdown]
# Congrats on getting this far! Here is a final question.
#
# **Question 8: interpolating latents**
#
# Estimated time: 30 min to 1 hour.
#
# Suppose the encoder is E, decoder is D. We essentially did the following: yhat = D(E(y)) where y is the input and yhat is the reconstructed image.
#
# Let z = E(y), so z is called the latent. Specifically, we obtain z after the batch normalization / pooling layers of the encoder.
#
# Now, let's try interpolating the z for one image and the z for another image!
#
# TODO:
# - Suppose the 0th image in the test set is called y0, and the 1st image in the test set is called y1. They correspond to latents z0 and z1 respectively.
# - Now, set new z by one of the following eleven choices and then print out the reconstructed image.
#   - z = 0.0 * z0 + 1.0 * z1
#   - z = 0.1 * z0 + 0.9 * z1
#   - z = 0.2 * z0 + 0.8 * z1
#   - ...
#   - z = 1.0 * z0 + 0.0 * z1
# - So, your result (to be submitted) should be...
#   - an image generated by the following latent: z = 0.0 * z0 + 1.0 * z1
#   - an image generated by the following latent: z = 0.1 * z0 + 0.9 * z1
#   - ...
#   - an image generated by the following latent: z = 1.0 * z0 + 0.0 * z1
# - Hint: you should see that your images gradually change from y1 to y0. If y1 is a tshirt and y0 is a shoe, then you should see that the images change gradually from a tshirt to a shoe.
# - You only need to do this for the regular CAE.
# - Explain clearly what your y1 is, and what your y0 is.
#
#
#
#
#
# Here is some code which may be helpful. You don't need to use the below.
# ```
#     model_children = list(model.children())
#     print("model children: ", model_children)
# ```
# You can use elements in model_children to process your inputs. You can also add another helper function (other than init and forward) in the CAE class. Your call!

# %%
autoencoder = CAE()
autoencoder.load_state_dict(torch.load(nondenoising_path)['model'])
autoencoder.cpu()
# Out:
# CAE(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): UpsamplingBilinear2d(scale_factor=2.0, mode=bilinear)
#     (4): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): UpsamplingBilinear2d(scale_factor=2.0, mode=bilinear)
#     (8): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
def visualize_one_model(model,test_loader, image_id, image_id2, gamma1):
    dataiter = iter(test_loader)
    images,_ = next(dataiter)
    if image_id  == 0:
      trial_image1 = images[:1]
    if image_id2  == 0:
      trial_image2 = images[:1]
    else:
      trial_image1 = images[image_id - 1:image_id]
      trial_image2 = images[image_id2 - 1:image_id2]
    z_0 = model.encoder(trial_image1)
    z_1 = model.encoder(trial_image2)
    z = gamma1*z_0 + (1-gamma1) * z_1
    z = model.decoder(z)
    z = torch.clamp(z, -1.0, 1.0)
    
    plt.figure()
    imshow(z.detach().squeeze(), figsize=(7,7), transpose=False)

# %%
for k in np.arange(0, 1.01, 0.1):
  print('k =', k)
  visualize_one_model(autoencoder,test_loader, 4, 5, k)
# Out:
# k = 0.0
# k = 0.1
# k = 0.2
# k = 0.30000000000000004
# k = 0.4
# k = 0.5
# k = 0.6000000000000001
# k = 0.7000000000000001
# k = 0.8
# k = 0.9
# k = 1.0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:78: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# The images are interpolating between a shirt and a pair of pants. We can see a fairly good interpolation, in which the collar of the shirt transforms into the top part of the pants. The shirt also thins out into the pants gradually over the course of the interpolation. Overall very cool!
